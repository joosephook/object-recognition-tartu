# %%
import pandas as pd
import numpy as np
from sklearn.multioutput import MultiOutputClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import cross_validate, KFold, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score

# %%
def labelstring(onehot: np.ndarray) -> str:
    labels = np.array([f'l{i}' for i in range(92)])
    return ' '.join(labels[onehot[0]])

# %%
train = np.load('clip_embeddings_train.npz')
X_train = train['embeddings'] 
y_train = train['labels_onehot']

# %%
xgb = XGBClassifier(random_state=111)

pipe = Pipeline(steps=[('classifier', MultiOutputClassifier(xgb))])

# %%
pipe.get_params
# Out:
# <bound method Pipeline.get_params of Pipeline(steps=[('xgb',
#                  MultiOutputClassifier(estimator=XGBClassifier(base_score=None,
#                                                                booster=None,
#                                                                callbacks=None,
#                                                                colsample_bylevel=None,
#                                                                colsample_bynode=None,
#                                                                colsample_bytree=None,
#                                                                early_stopping_rounds=None,
#                                                                enable_categorical=False,
#                                                                eval_metric=None,
#                                                                feature_types=None,
#                                                                gamma=None,
#                                                                gpu_id=None,
#                                                                grow_policy=None,
#                                                                importance_type=None,
#                                                                interaction_constraints=None,
#                                                                learning_rate=None,
#                                                                max_bin=None,
#                                                                max_cat_threshold=None,
#                                                                max_cat_to_onehot=None,
#                                                                max_delta_step=None,
#                                                                max_depth=None,
#                                                                max_leaves=None,
#                                                                min_child_weight=None,
#                                                                missing=nan,
#                                                                monotone_constraints=None,
#                                                                n_estimators=100,
#                                                                n_jobs=None,
#                                                                num_parallel_tree=None,
#                                                                predictor=None,
#                                                                random_state=111, ...)))])>

# %%
search_grid = {
    'classifier__estimator__n_estimators': [100, 200, 500],
    'classifier__estimator__learning_rate': [0.01,0.05,0.1],
    'classifier__estimator__booster': ['gbtree', 'gblinear'],
    'classifier__estimator__gamma': [0, 0.5, 1],
    'classifier__estimator__reg_alpha': [0, 0.5, 1],
    'classifier__estimator__reg_lambda': [0.5, 1, 5],
    'classifier__estimator__scale_pos_weight': [40, 60, 80, 90, 100], #default is 1, lower values than 40 were tested beforehand
    'classifier__estimator__max_delta_step': [5, 7, 10] #default is 0, lower values than 5 were tested beforehand

}

# %%
#clf = GridSearchCV(MultiOutputClassifier(XGBClassifier(n_jobs=-1)), params, n_jobs=-1, cv=KFold(n_splits=3), scoring='f1') #GridSearch is too slow
clf = RandomizedSearchCV(estimator=pipe, param_distributions=search_grid, scoring='f1_macro', refit='f1_macro', error_score='raise', cv=KFold(n_splits=3),
                         n_jobs=-1, verbose=1)
clf.fit(X_train, y_train)
print('Best score:', clf.best_score_)
print('Best score:', clf.best_params_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [21:47:27] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:27] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:28] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:28] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:29] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:31] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:31] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:33] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:33] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:34] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:34] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:35] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:35] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:36] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:36] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:37] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:37] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:38] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:38] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:38] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:40] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:40] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:40] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:41] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:41] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:41] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:46] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:46] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:47] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:47] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:47] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:49] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:49] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:49] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:53] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:53] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:53] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:54] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:54] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:54] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:55] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:55] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:56] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:56] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:59] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:47:59] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:00] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:00] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:00] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:01] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:01] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:01] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:02] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:02] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# [21:48:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "gamma", "max_delta_step" } are not used.
#
# Best score: 0.32343721562971955
# Best score: {'classifier__estimator__scale_pos_weight': 100, 'classifier__estimator__reg_lambda': 0.5, 'classifier__estimator__reg_alpha': 0, 'classifier__estimator__n_estimators': 500, 'classifier__estimator__max_delta_step': 7, 'classifier__estimator__learning_rate': 0.1, 'classifier__estimator__gamma': 1, 'classifier__estimator__booster': 'gblinear'}

# %%
print('Best score:', clf.cv_results_)
# Out:
# Best score: {'mean_fit_time': array([ 62.13891244,  10.47386781, 101.21870224, 129.85644579,
#        502.63166761,  96.32724778, 247.16782212,  41.09370875,
#        523.7465806 , 363.54213142]), 'std_fit_time': array([  0.17350486,   1.53346057,   1.89283739,   8.60227756,
#          5.11473678,  12.76480613,  17.60288055,   4.55973921,
#         10.38225148, 114.45790044]), 'mean_score_time': array([0.60443568, 0.43466663, 0.66533478, 0.53394667, 0.67622073,
#        0.84887513, 0.584946  , 0.50725293, 0.64711428, 0.6163427 ]), 'std_score_time': array([0.08356486, 0.04553418, 0.18219786, 0.04333244, 0.04450806,
#        0.19363687, 0.02929463, 0.03107154, 0.02736006, 0.04450605]), 'param_classifier__estimator__scale_pos_weight': masked_array(data=[40, 80, 80, 100, 80, 90, 90, 90, 80, 90],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_classifier__estimator__reg_lambda': masked_array(data=[5, 5, 1, 0.5, 1, 0.5, 1, 0.5, 0.5, 1],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_classifier__estimator__reg_alpha': masked_array(data=[0.5, 0.5, 1, 0, 0.5, 0.5, 0, 1, 0.5, 0.5],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_classifier__estimator__n_estimators': masked_array(data=[500, 100, 200, 500, 500, 100, 500, 200, 500, 500],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_classifier__estimator__max_delta_step': masked_array(data=[5, 7, 10, 7, 5, 10, 10, 5, 10, 10],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_classifier__estimator__learning_rate': masked_array(data=[0.1, 0.1, 0.1, 0.1, 0.01, 0.1, 0.1, 0.01, 0.01, 0.01],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_classifier__estimator__gamma': masked_array(data=[0.5, 0.5, 0, 1, 1, 1, 0.5, 0, 0.5, 0.5],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_classifier__estimator__booster': masked_array(data=['gblinear', 'gblinear', 'gbtree', 'gblinear', 'gbtree',
#                    'gbtree', 'gbtree', 'gblinear', 'gbtree', 'gbtree'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'classifier__estimator__scale_pos_weight': 40, 'classifier__estimator__reg_lambda': 5, 'classifier__estimator__reg_alpha': 0.5, 'classifier__estimator__n_estimators': 500, 'classifier__estimator__max_delta_step': 5, 'classifier__estimator__learning_rate': 0.1, 'classifier__estimator__gamma': 0.5, 'classifier__estimator__booster': 'gblinear'}, {'classifier__estimator__scale_pos_weight': 80, 'classifier__estimator__reg_lambda': 5, 'classifier__estimator__reg_alpha': 0.5, 'classifier__estimator__n_estimators': 100, 'classifier__estimator__max_delta_step': 7, 'classifier__estimator__learning_rate': 0.1, 'classifier__estimator__gamma': 0.5, 'classifier__estimator__booster': 'gblinear'}, {'classifier__estimator__scale_pos_weight': 80, 'classifier__estimator__reg_lambda': 1, 'classifier__estimator__reg_alpha': 1, 'classifier__estimator__n_estimators': 200, 'classifier__estimator__max_delta_step': 10, 'classifier__estimator__learning_rate': 0.1, 'classifier__estimator__gamma': 0, 'classifier__estimator__booster': 'gbtree'}, {'classifier__estimator__scale_pos_weight': 100, 'classifier__estimator__reg_lambda': 0.5, 'classifier__estimator__reg_alpha': 0, 'classifier__estimator__n_estimators': 500, 'classifier__estimator__max_delta_step': 7, 'classifier__estimator__learning_rate': 0.1, 'classifier__estimator__gamma': 1, 'classifier__estimator__booster': 'gblinear'}, {'classifier__estimator__scale_pos_weight': 80, 'classifier__estimator__reg_lambda': 1, 'classifier__estimator__reg_alpha': 0.5, 'classifier__estimator__n_estimators': 500, 'classifier__estimator__max_delta_step': 5, 'classifier__estimator__learning_rate': 0.01, 'classifier__estimator__gamma': 1, 'classifier__estimator__booster': 'gbtree'}, {'classifier__estimator__scale_pos_weight': 90, 'classifier__estimator__reg_lambda': 0.5, 'classifier__estimator__reg_alpha': 0.5, 'classifier__estimator__n_estimators': 100, 'classifier__estimator__max_delta_step': 10, 'classifier__estimator__learning_rate': 0.1, 'classifier__estimator__gamma': 1, 'classifier__estimator__booster': 'gbtree'}, {'classifier__estimator__scale_pos_weight': 90, 'classifier__estimator__reg_lambda': 1, 'classifier__estimator__reg_alpha': 0, 'classifier__estimator__n_estimators': 500, 'classifier__estimator__max_delta_step': 10, 'classifier__estimator__learning_rate': 0.1, 'classifier__estimator__gamma': 0.5, 'classifier__estimator__booster': 'gbtree'}, {'classifier__estimator__scale_pos_weight': 90, 'classifier__estimator__reg_lambda': 0.5, 'classifier__estimator__reg_alpha': 1, 'classifier__estimator__n_estimators': 200, 'classifier__estimator__max_delta_step': 5, 'classifier__estimator__learning_rate': 0.01, 'classifier__estimator__gamma': 0, 'classifier__estimator__booster': 'gblinear'}, {'classifier__estimator__scale_pos_weight': 80, 'classifier__estimator__reg_lambda': 0.5, 'classifier__estimator__reg_alpha': 0.5, 'classifier__estimator__n_estimators': 500, 'classifier__estimator__max_delta_step': 10, 'classifier__estimator__learning_rate': 0.01, 'classifier__estimator__gamma': 0.5, 'classifier__estimator__booster': 'gbtree'}, {'classifier__estimator__scale_pos_weight': 90, 'classifier__estimator__reg_lambda': 1, 'classifier__estimator__reg_alpha': 0.5, 'classifier__estimator__n_estimators': 500, 'classifier__estimator__max_delta_step': 10, 'classifier__estimator__learning_rate': 0.01, 'classifier__estimator__gamma': 0.5, 'classifier__estimator__booster': 'gbtree'}], 'split0_test_score': array([0.0655911 , 0.07618344, 0.15904827, 0.36087974, 0.15675816,
#        0.15904179, 0.1602276 , 0.07075582, 0.15315683, 0.15576998]), 'split1_test_score': array([0.05740989, 0.07138913, 0.11858455, 0.30676128, 0.1169694 ,
#        0.12103129, 0.12084185, 0.0702728 , 0.11744881, 0.11877877]), 'split2_test_score': array([0.0623953 , 0.07247261, 0.20539948, 0.30267063, 0.20128191,
#        0.20510021, 0.21382454, 0.07005458, 0.19901479, 0.20187148]), 'mean_test_score': array([0.06179876, 0.07334839, 0.16101077, 0.32343722, 0.15833649,
#        0.16172443, 0.16496466, 0.07036107, 0.15654014, 0.15880674]), 'std_test_score': array([0.0033665 , 0.0020529 , 0.03546921, 0.02652848, 0.03443853,
#        0.03437337, 0.03810752, 0.000293  , 0.033385  , 0.03399035]), 'rank_test_score': array([10,  8,  4,  1,  6,  3,  2,  9,  7,  5])}

# %%
prediction_on_train = clf.predict(X_train)

# %%
print(f'f1 score: {f1_score(y_train, prediction_on_train, average="macro"):.3f}')
print(clf.score(X_train, y_train))
# Out:
# f1 score: 0.652
# 0.651736031373183

# %%
test = np.load('clip_embeddings_test.npz', allow_pickle=True)
X_test = test['embeddings']
test_img_ids = test['img_id']

testdf = pd.read_csv('test.csv')

# %%
labelsdf = pd.read_csv('labels.csv')
testlabels = []

for img_id in testdf['image_id']:
    if img_id in test_img_ids:
        prediction = clf.predict(test['embeddings'][img_id == test_img_ids].reshape(1,-1))
        predicted_labels = labelstring(prediction.astype(bool))
        if len(predicted_labels) == 0:
            testlabels.append('l1')
        else:
            testlabels.append(predicted_labels)
        print('='*40)
        print(img_id)
        print(labelsdf.loc[labelsdf.label_id.isin(testlabels[-1].split(' ')), 'object'])
        print('='*40)
    else:
        # default label for the missing images in our test set
        print('test image', img_id, 'missing from images')
        testlabels.append('l0')


testdf['labels'] = testlabels
testdf.to_csv('kea_submissions/clip_xgboost_cv1.csv', index=False)
# Out:
# ========================================
# img102.jpg
# 0                                people
# 1                                 trees
# 3                              building
# 5                             buildings
# 6                                 water
# 7                                  road
# 9                                  cars
# 10                               nature
# 12                             pavement
# 15                           lamp posts
# 20                               bridge
# 23                               street
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 32                             blue sky
# 39                                flags
# 41                    drone photography
# 48                             fountain
# 59                                 park
# 80                               lights
# 86                                tents
# Name: object, dtype: object
# ========================================
# ========================================
# img103.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 7           road
# 9           cars
# 10        nature
# 11       bicycle
# 12      pavement
# 15    lamp posts
# 18        stairs
# 20        bridge
# 27          tree
# 30         bench
# 43     lamp post
# Name: object, dtype: object
# ========================================
# ========================================
# img11.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 8            person
# 9              cars
# 14    traffic signs
# 16     traffic sign
# 17           winter
# 23           street
# 42          tractor
# 56            fence
# 69        snow plow
# 85         stroller
# Name: object, dtype: object
# ========================================
# ========================================
# img113.jpg
# 0      people
# 1       trees
# 2       grass
# 6       water
# 8      person
# 10     nature
# 13    flowers
# 51     plants
# 70     leaves
# Name: object, dtype: object
# ========================================
# ========================================
# img114.jpg
# 0      people
# 1       trees
# 2       grass
# 10     nature
# 13    flowers
# 51     plants
# Name: object, dtype: object
# ========================================
# ========================================
# img121.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 6          water
# 7           road
# 19        clouds
# 22          sand
# 31    playground
# 32      blue sky
# 34         sunny
# 43     lamp post
# 54         beach
# Name: object, dtype: object
# ========================================
# ========================================
# img126.jpg
# 0                         people
# 1                          trees
# 2                          grass
# 5                      buildings
# 6                          water
# 10                        nature
# 19                        clouds
# 22                          sand
# 31                    playground
# 38                         barge
# 40    emajõe-peipsi barge jõmmu
# 43                     lamp post
# 54                         beach
# Name: object, dtype: object
# ========================================
# ========================================
# img131.jpg
# 0       people
# 3     building
# 7         road
# 8       person
# 13     flowers
# 44     glasses
# Name: object, dtype: object
# ========================================
# ========================================
# img136.jpg
# 0       people
# 3     building
# 8       person
# 44     glasses
# 66       chair
# 84      pencil
# Name: object, dtype: object
# ========================================
# ========================================
# img137.jpg
# 0           people
# 1            trees
# 2            grass
# 3         building
# 4             snow
# 5        buildings
# 7             road
# 10          nature
# 12        pavement
# 16    traffic sign
# 18          stairs
# 27            tree
# 43       lamp post
# 59            park
# 80          lights
# Name: object, dtype: object
# ========================================
# ========================================
# img139.jpg
# 0        people
# 1         trees
# 2         grass
# 3      building
# 4          snow
# 7          road
# 10       nature
# 17       winter
# 18       stairs
# 27         tree
# 43    lamp post
# 59         park
# Name: object, dtype: object
# ========================================
# ========================================
# img140.jpg
# 0          people
# 1           trees
# 2           grass
# 3        building
# 4            snow
# 5       buildings
# 6           water
# 7            road
# 9            cars
# 19         clouds
# 22           sand
# 27           tree
# 31     playground
# 32       blue sky
# 43      lamp post
# 49          river
# 54          beach
# 74    outdoor gym
# Name: object, dtype: object
# ========================================
# ========================================
# img15.jpg
# 1                 trees
# 2                 grass
# 3              building
# 7                  road
# 8                person
# 13              flowers
# 15           lamp posts
# 53    green garbage can
# 91                 pole
# Name: object, dtype: object
# ========================================
# ========================================
# img150.jpg
# 0            people
# 1             trees
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 8            person
# 9              cars
# 11          bicycle
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 50              car
# Name: object, dtype: object
# ========================================
# ========================================
# img151.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 5         buildings
# 7              road
# 9              cars
# 11          bicycle
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 23           street
# 32         blue sky
# 43        lamp post
# 50              car
# Name: object, dtype: object
# ========================================
# ========================================
# img152.jpg
# 0            people
# 1             trees
# 3          building
# 5         buildings
# 7              road
# 9              cars
# 11          bicycle
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 23           street
# 50              car
# 52          red bus
# Name: object, dtype: object
# ========================================
# ========================================
# img156.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 9              cars
# 11          bicycle
# 12         pavement
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 27             tree
# 32         blue sky
# 43        lamp post
# Name: object, dtype: object
# ========================================
# ========================================
# img161.jpg
# 0                         people
# 1                          trees
# 2                          grass
# 5                      buildings
# 6                          water
# 10                        nature
# 19                        clouds
# 20                        bridge
# 32                      blue sky
# 38                         barge
# 40    emajõe-peipsi barge jõmmu
# 61                          boat
# Name: object, dtype: object
# ========================================
# ========================================
# img166.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 5         buildings
# 7              road
# 8            person
# 10           nature
# 11          bicycle
# 12         pavement
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 21       stone road
# 30            bench
# 76        crosswalk
# Name: object, dtype: object
# ========================================
# ========================================
# img167.jpg
# 0       people
# 1        trees
# 2        grass
# 3     building
# 4         snow
# 6        water
# 8       person
# 9         cars
# 11     bicycle
# Name: object, dtype: object
# ========================================
# ========================================
# img170.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 7           road
# 8         person
# 19        clouds
# 21    stone road
# 43     lamp post
# 83         table
# Name: object, dtype: object
# ========================================
# ========================================
# img173.jpg
# 0          people
# 1           trees
# 2           grass
# 3        building
# 4            snow
# 8          person
# 10         nature
# 12       pavement
# 17         winter
# 18         stairs
# 27           tree
# 37    chain light
# 80         lights
# Name: object, dtype: object
# ========================================
# ========================================
# img176.jpg
# 0          people
# 1           trees
# 2           grass
# 3        building
# 4            snow
# 5       buildings
# 6           water
# 8          person
# 12       pavement
# 17         winter
# 18         stairs
# 23         street
# 27           tree
# 33       children
# 37    chain light
# 56          fence
# 85       stroller
# Name: object, dtype: object
# ========================================
# ========================================
# img18.jpg
# 0                people
# 1                 trees
# 2                 grass
# 3              building
# 4                  snow
# 5             buildings
# 7                  road
# 10               nature
# 13              flowers
# 16         traffic sign
# 18               stairs
# 23               street
# 43            lamp post
# 53    green garbage can
# 73                house
# Name: object, dtype: object
# ========================================
# ========================================
# img180.jpg
# 0        people
# 1         trees
# 2         grass
# 3      building
# 5     buildings
# 7          road
# 8        person
# 11      bicycle
# 27         tree
# 30        bench
# 46       bushes
# 55      benches
# Name: object, dtype: object
# ========================================
# ========================================
# img181.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 7           road
# 8         person
# 9           cars
# 10        nature
# 11       bicycle
# 12      pavement
# 15    lamp posts
# 33      children
# 43     lamp post
# 52       red bus
# Name: object, dtype: object
# ========================================
# ========================================
# img182.jpg
# 0          people
# 1           trees
# 2           grass
# 3        building
# 5       buildings
# 7            road
# 8          person
# 10         nature
# 11        bicycle
# 18         stairs
# 21     stone road
# 22           sand
# 30          bench
# 31     playground
# 33       children
# 43      lamp post
# 74    outdoor gym
# Name: object, dtype: object
# ========================================
# ========================================
# img183.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 6          water
# 7           road
# 9           cars
# 10        nature
# 15    lamp posts
# 18        stairs
# 19        clouds
# 20        bridge
# Name: object, dtype: object
# ========================================
# ========================================
# img189.jpg
# 0                         people
# 1                          trees
# 2                          grass
# 3                       building
# 5                      buildings
# 6                          water
# 7                           road
# 9                           cars
# 12                      pavement
# 19                        clouds
# 20                        bridge
# 22                          sand
# 32                      blue sky
# 38                         barge
# 39                         flags
# 40    emajõe-peipsi barge jõmmu
# 41             drone photography
# 49                         river
# 61                          boat
# Name: object, dtype: object
# ========================================
# ========================================
# img192.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 4           snow
# 5      buildings
# 7           road
# 8         person
# 10        nature
# 11       bicycle
# 12      pavement
# 18        stairs
# 22          sand
# 27          tree
# 30         bench
# 31    playground
# 33      children
# 43     lamp post
# 62         child
# Name: object, dtype: object
# ========================================
# ========================================
# img194.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 5         buildings
# 6             water
# 7              road
# 8            person
# 12         pavement
# 13          flowers
# 14    traffic signs
# 27             tree
# 33         children
# 43        lamp post
# 55          benches
# Name: object, dtype: object
# ========================================
# ========================================
# img195.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 4           snow
# 5      buildings
# 6          water
# 7           road
# 8         person
# 22          sand
# 31    playground
# 33      children
# Name: object, dtype: object
# ========================================
# ========================================
# img206.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 6          water
# 7           road
# 9           cars
# 10        nature
# 11       bicycle
# 12      pavement
# 15    lamp posts
# 19        clouds
# 20        bridge
# 43     lamp post
# Name: object, dtype: object
# ========================================
# ========================================
# img208.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 7           road
# 10        nature
# 12      pavement
# 13       flowers
# 15    lamp posts
# 23        street
# 51        plants
# Name: object, dtype: object
# ========================================
# ========================================
# img209.jpg
# 0            people
# 1             trees
# 2             grass
# 5         buildings
# 6             water
# 7              road
# 9              cars
# 10           nature
# 12         pavement
# 13          flowers
# 15       lamp posts
# 19           clouds
# 20           bridge
# 30            bench
# 32         blue sky
# 36    yellow leaves
# 47           autumn
# 55          benches
# 70           leaves
# Name: object, dtype: object
# ========================================
# ========================================
# img211.jpg
# 0                                people
# 1                                 trees
# 2                                 grass
# 3                              building
# 5                             buildings
# 6                                 water
# 7                                  road
# 9                                  cars
# 10                               nature
# 12                             pavement
# 13                              flowers
# 15                           lamp posts
# 18                               stairs
# 23                               street
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 32                             blue sky
# 39                                flags
# 43                            lamp post
# Name: object, dtype: object
# ========================================
# ========================================
# img212.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 4           snow
# 5      buildings
# 7           road
# 9           cars
# 10        nature
# 12      pavement
# 13       flowers
# 15    lamp posts
# 18        stairs
# 27          tree
# 43     lamp post
# 55       benches
# Name: object, dtype: object
# ========================================
# ========================================
# img218.jpg
# 0            people
# 1             trees
# 2             grass
# 8            person
# 10           nature
# 12         pavement
# 13          flowers
# 30            bench
# 36    yellow leaves
# 47           autumn
# 70           leaves
# 78              man
# 88             book
# Name: object, dtype: object
# ========================================
# ========================================
# img22.jpg
# 0             people
# 1              trees
# 2              grass
# 3           building
# 5          buildings
# 7               road
# 9               cars
# 10            nature
# 11           bicycle
# 12          pavement
# 15        lamp posts
# 18            stairs
# 21        stone road
# 27              tree
# 43         lamp post
# 47            autumn
# 59              park
# 71    stair railings
# Name: object, dtype: object
# ========================================
# ========================================
# img221.jpg
# 0                                people
# 1                                 trees
# 3                              building
# 5                             buildings
# 6                                 water
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 39                                flags
# 48                             fountain
# Name: object, dtype: object
# ========================================
# ========================================
# img228.jpg
# 0            people
# 1             trees
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 8            person
# 9              cars
# 14    traffic signs
# 16     traffic sign
# 17           winter
# 23           street
# 42          tractor
# 50              car
# 52          red bus
# 69        snow plow
# Name: object, dtype: object
# ========================================
# ========================================
# img230.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 9              cars
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 17           winter
# 23           street
# 27             tree
# 42          tractor
# 50              car
# 52          red bus
# 69        snow plow
# 85         stroller
# Name: object, dtype: object
# ========================================
# ========================================
# img231.jpg
# 0            people
# 1             trees
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 9              cars
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 17           winter
# 23           street
# 27             tree
# 42          tractor
# 50              car
# 52          red bus
# 69        snow plow
# Name: object, dtype: object
# ========================================
# ========================================
# img234.jpg
# 0           people
# 1            trees
# 3         building
# 4             snow
# 5        buildings
# 7             road
# 9             cars
# 16    traffic sign
# 17          winter
# 23          street
# 27            tree
# 42         tractor
# 50             car
# 69       snow plow
# Name: object, dtype: object
# ========================================
# ========================================
# img238.jpg
# 0        people
# 1         trees
# 3      building
# 5     buildings
# 7          road
# 8        person
# 9          cars
# 11      bicycle
# 12     pavement
# 30        bench
# 33     children
# 52      red bus
# Name: object, dtype: object
# ========================================
# ========================================
# img243.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 5         buildings
# 6             water
# 7              road
# 9              cars
# 10           nature
# 11          bicycle
# 12         pavement
# 15       lamp posts
# 19           clouds
# 20           bridge
# 32         blue sky
# 36    yellow leaves
# 47           autumn
# Name: object, dtype: object
# ========================================
# ========================================
# img247.jpg
# 0           people
# 1            trees
# 2            grass
# 3         building
# 5        buildings
# 6            water
# 7             road
# 9             cars
# 10          nature
# 12        pavement
# 15      lamp posts
# 16    traffic sign
# 19          clouds
# 20          bridge
# 23          street
# 32        blue sky
# 43       lamp post
# Name: object, dtype: object
# ========================================
# ========================================
# img248.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 7           road
# 8         person
# 21    stone road
# 25      graffiti
# 29          wall
# Name: object, dtype: object
# ========================================
# ========================================
# img249.jpg
# 0       people
# 1        trees
# 2        grass
# 7         road
# 25    graffiti
# 29        wall
# Name: object, dtype: object
# ========================================
# ========================================
# img250.jpg
# 0           people
# 1            trees
# 2            grass
# 3         building
# 5        buildings
# 7             road
# 9             cars
# 13         flowers
# 16    traffic sign
# 18          stairs
# 23          street
# 25        graffiti
# 29            wall
# 73           house
# Name: object, dtype: object
# ========================================
# ========================================
# img251.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 5      buildings
# 7           road
# 8         person
# 9           cars
# 11       bicycle
# 12      pavement
# 15    lamp posts
# 27          tree
# 52       red bus
# Name: object, dtype: object
# ========================================
# ========================================
# img252.jpg
# 0       people
# 1        trees
# 2        grass
# 3     building
# 7         road
# 8       person
# 9         cars
# 25    graffiti
# 29        wall
# Name: object, dtype: object
# ========================================
# ========================================
# img257.jpg
# 0         people
# 1          trees
# 2          grass
# 3       building
# 4           snow
# 5      buildings
# 7           road
# 13       flowers
# 15    lamp posts
# 18        stairs
# 21    stone road
# 27          tree
# 43     lamp post
# 55       benches
# Name: object, dtype: object
# ========================================
# ========================================
# img259.jpg
# 0                 people
# 1                  trees
# 2                  grass
# 3               building
# 5              buildings
# 8                 person
# 11               bicycle
# 18                stairs
# 24    town hall of tartu
# 26         estonian flag
# 27                  tree
# 39                 flags
# Name: object, dtype: object
# ========================================
# ========================================
# img262.jpg
# 0       people
# 1        trees
# 2        grass
# 3     building
# 8       person
# 12    pavement
# 30       bench
# 66       chair
# 84      pencil
# 88        book
# Name: object, dtype: object
# ========================================
# ========================================
# img265.jpg
# 0       people
# 3     building
# 8       person
# 18      stairs
# 27        tree
# Name: object, dtype: object
# ========================================
# ========================================
# img266.jpg
# 0                 people
# 1                  trees
# 2                  grass
# 3               building
# 5              buildings
# 6                  water
# 7                   road
# 9                   cars
# 15            lamp posts
# 20                bridge
# 24    town hall of tartu
# 26         estonian flag
# 32              blue sky
# 39                 flags
# 41     drone photography
# 80                lights
# Name: object, dtype: object
# ========================================
# ========================================
# img279.jpg
# 0                                people
# 1                                 trees
# 3                              building
# 4                                  snow
# 5                             buildings
# 6                                 water
# 9                                  cars
# 15                           lamp posts
# 19                               clouds
# 20                               bridge
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 32                             blue sky
# 38                                barge
# 40           emajõe-peipsi barge jõmmu
# 48                             fountain
# Name: object, dtype: object
# ========================================
# ========================================
# img280.jpg
# 0          people
# 1           trees
# 3        building
# 4            snow
# 5       buildings
# 7            road
# 9            cars
# 12       pavement
# 17         winter
# 23         street
# 37    chain light
# 80         lights
# Name: object, dtype: object
# ========================================
# ========================================
# img281.jpg
# 0                 people
# 1                  trees
# 3               building
# 4                   snow
# 5              buildings
# 6                  water
# 9                   cars
# 12              pavement
# 15            lamp posts
# 17                winter
# 24    town hall of tartu
# 26         estonian flag
# 37           chain light
# 39                 flags
# 41     drone photography
# 80                lights
# 87                 stage
# Name: object, dtype: object
# ========================================
# test image img285.jpg missing from images
# test image img288.jpg missing from images
# ========================================
# img292.jpg
# 0        people
# 1         trees
# 3      building
# 5     buildings
# 7          road
# 8        person
# 9          cars
# 10       nature
# 30        bench
# 44      glasses
# 66        chair
# 67      traffic
# Name: object, dtype: object
# ========================================
# ========================================
# img296.jpg
# 0                                people
# 1                                 trees
# 3                              building
# 5                             buildings
# 6                                 water
# 15                           lamp posts
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 32                             blue sky
# 39                                flags
# 41                    drone photography
# 48                             fountain
# Name: object, dtype: object
# ========================================
# ========================================
# img3.jpg
# 0           people
# 1            trees
# 2            grass
# 3         building
# 4             snow
# 5        buildings
# 7             road
# 9             cars
# 15      lamp posts
# 16    traffic sign
# 17          winter
# 23          street
# 27            tree
# 39           flags
# 43       lamp post
# 45          cloudy
# 81        suitcase
# Name: object, dtype: object
# ========================================
# ========================================
# img300.jpg
# 0                                people
# 1                                 trees
# 3                              building
# 5                             buildings
# 6                                 water
# 9                                  cars
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 32                             blue sky
# 39                                flags
# 41                    drone photography
# 48                             fountain
# Name: object, dtype: object
# ========================================
# ========================================
# img33.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 4              snow
# 6             water
# 8            person
# 10           nature
# 12         pavement
# 27             tree
# 35              dog
# 36    yellow leaves
# 56            fence
# 64              cat
# Name: object, dtype: object
# ========================================
# ========================================
# img37.jpg
# 0            people
# 1             trees
# 2             grass
# 8            person
# 10           nature
# 12         pavement
# 21       stone road
# 35              dog
# 36    yellow leaves
# 47           autumn
# 55          benches
# 70           leaves
# 85         stroller
# Name: object, dtype: object
# ========================================
# ========================================
# img39.jpg
# 0            people
# 1             trees
# 3          building
# 4              snow
# 8            person
# 11          bicycle
# 12         pavement
# 14    traffic signs
# 17           winter
# 21       stone road
# 27             tree
# 35              dog
# 55          benches
# 85         stroller
# Name: object, dtype: object
# ========================================
# ========================================
# img41.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 5         buildings
# 7              road
# 9              cars
# 11          bicycle
# 12         pavement
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 18           stairs
# 21       stone road
# 27             tree
# Name: object, dtype: object
# ========================================
# ========================================
# img42.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 5         buildings
# 7              road
# 8            person
# 9              cars
# 12         pavement
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 27             tree
# Name: object, dtype: object
# ========================================
# ========================================
# img43.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 9              cars
# 12         pavement
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 27             tree
# Name: object, dtype: object
# ========================================
# ========================================
# img48.jpg
# 0           people
# 1            trees
# 2            grass
# 3         building
# 5        buildings
# 7             road
# 9             cars
# 15      lamp posts
# 16    traffic sign
# 32        blue sky
# 45          cloudy
# 67         traffic
# Name: object, dtype: object
# ========================================
# ========================================
# img49.jpg
# 0            people
# 1             trees
# 2             grass
# 3          building
# 4              snow
# 5         buildings
# 7              road
# 8            person
# 11          bicycle
# 12         pavement
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 30            bench
# Name: object, dtype: object
# ========================================
# ========================================
# img5.jpg
# 0       people
# 3     building
# 4         snow
# 6        water
# 7         road
# 17      winter
# 19      clouds
# 27        tree
# 58      worker
# 63       plane
# 79        cone
# 81    suitcase
# Name: object, dtype: object
# ========================================
# ========================================
# img57.jpg
# 0            people
# 1             trees
# 3          building
# 7              road
# 8            person
# 9              cars
# 10           nature
# 11          bicycle
# 14    traffic signs
# 15       lamp posts
# 30            bench
# 34            sunny
# 52          red bus
# Name: object, dtype: object
# ========================================
# ========================================
# img59.jpg
# 0            people
# 1             trees
# 3          building
# 5         buildings
# 7              road
# 9              cars
# 11          bicycle
# 12         pavement
# 14    traffic signs
# 15       lamp posts
# 16     traffic sign
# 20           bridge
# 34            sunny
# 45           cloudy
# 67          traffic
# Name: object, dtype: object
# ========================================
# ========================================
# img69.jpg
# 0                                people
# 1                                 trees
# 3                              building
# 5                             buildings
# 6                                 water
# 7                                  road
# 9                                  cars
# 15                           lamp posts
# 23                               street
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 32                             blue sky
# 39                                flags
# 41                    drone photography
# 48                             fountain
# 59                                 park
# 86                                tents
# Name: object, dtype: object
# ========================================
# ========================================
# img71.jpg
# 0            people
# 1             trees
# 3          building
# 5         buildings
# 8            person
# 11          bicycle
# 26    estonian flag
# 57       performing
# Name: object, dtype: object
# ========================================
# ========================================
# img73.jpg
# 0         people
# 1          trees
# 8         person
# 35           dog
# 57    performing
# 66         chair
# Name: object, dtype: object
# ========================================
# ========================================
# img75.jpg
# 0                                people
# 1                                 trees
# 3                              building
# 5                             buildings
# 6                                 water
# 7                                  road
# 11                              bicycle
# 13                              flowers
# 24                   town hall of tartu
# 26                        estonian flag
# 28    the sculpture of kissing students
# 39                                flags
# 41                    drone photography
# 57                           performing
# 86                                tents
# Name: object, dtype: object
# ========================================
# ========================================
# img79.jpg
# 0         people
# 2          grass
# 8         person
# 12      pavement
# 21    stone road
# 35           dog
# 56         fence
# 62         child
# Name: object, dtype: object
# ========================================
# ========================================
# img8.jpg
# 0       people
# 1        trees
# 3     building
# 4         snow
# 8       person
# 9         cars
# 17      winter
# 27        tree
# Name: object, dtype: object
# ========================================
# ========================================
# img81.jpg
# 0    people
# 2     grass
# 6     water
# 8    person
# Name: object, dtype: object
# ========================================
# ========================================
# img84.jpg
# 0      people
# 8      person
# 13    flowers
# 60    wedding
# 68       suit
# 75      hands
# Name: object, dtype: object
# ========================================
# ========================================
# img90.jpg
# 0            people
# 1             trees
# 3          building
# 8            person
# 11          bicycle
# 26    estonian flag
# 62            child
# 90             flag
# Name: object, dtype: object
# ========================================
# ========================================
# img93.jpg
# 0      people
# 2       grass
# 6       water
# 13    flowers
# 51     plants
# Name: object, dtype: object
# ========================================
# ========================================
# img94.jpg
# 0      people
# 1       trees
# 8      person
# 13    flowers
# 66      chair
# Name: object, dtype: object
# ========================================
